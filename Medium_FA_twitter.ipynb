# %% [markdown]
# #Food Assistance Tweets: Scraping and Topic Modelling Part 1

# %% [markdown]
# Code adapted from: https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a

# %% [markdown]
# ## Set up libraries

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
# Twitter API Authentication with OAuth2 Bearer Token
bearer_token = '<insert your bearer token>'

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 500):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
headers = create_headers(bearer_token)
keyword = "food emergency OR food aid OR #freefood OR #mealservice OR covid food"
start_time = "2020-03-01T00:00:00.00Z"
end_time = "2020-04-01T00:00:00.00Z"
max_results = 500

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "312551423",
#             "conversation_id": "1245138803695611905",
#             "created_at": "2020-03-31T23:59:59.000Z",
#             "id": "1245138803695611905",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 329
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245055880183177216",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @SinghLions: Proud to be Sikh! Gurdwara Sahib in Malerkotla, Punjab has been serving food to Muslim students since #Lockdown. The local\u2026"
#         },
#         {
#             "author_id": "62448338",
#             "conversation_id": "1245138803091636225",
#             "created_at": "2020-03-31T23:59:58.000Z",
#             "id": "1245138803091636225",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 119
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245079745538084864",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @CAgovernor: During CA\u2019s stay at home order, older Californians may need friends &amp; neighbors to obtain basic necessities like groceries\u2026"
#         },
#         {
#             "author_id": "75966161",
#             "conversation_id": "1245138791762989062",
#             "created_at": "2020-03-31T23:59:56.000Z",
#             "id": "1245138791762989062",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 7
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245046523735441414",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @DetroitParksRec: More resources are available to assist families, parents, and children with food. Meal distributions will be available\u2026"
#         },
#         {
#             "author_id": "138999222",
#             "conversation_id": "1245138748850851840",
#             "created_at": "2020-03-31T23:59:45.000Z",
#             "id": "1245138748850851840",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "16731956",
#             "conversation_id": "1245138714877181955",
#             "created_at": "2020-03-31T23:59:37.000Z",
#             "id": "1245138714877181955",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "2929820271",
#             "conversation_id": "1245138696246104064",
#             "created_at": "2020-03-31T23:59:33.000Z",
#             "id": "1245138696246104064",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245019220418670592",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @NatCremation: Our gratitude to every one of you who continue to work so we can have what we need during this difficult time \u2013 truck dri\u2026"
#         },
#         {
#             "author_id": "10502292",
#             "conversation_id": "1245138690143219712",
#             "created_at": "2020-03-31T23:59:31.000Z",
#             "id": "1245138690143219712",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "1171839758781374465",
#             "conversation_id": "1245138625026637825",
#             "created_at": "2020-03-31T23:59:16.000Z",
#             "id": "1245138625026637825",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 498
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245087302331715585",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @cjwerleman: With no medical equipment and diminishing food supplies, Rohingya Muslim refugees have been left alone as COVID-19 stalks t\u2026"
#         },
#         {
#             "author_id": "2326269009",
#             "conversation_id": "1245138621189029891",
#             "created_at": "2020-03-31T23:59:15.000Z",
#             "id": "1245138621189029891",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "2475999258",
#             "conversation_id": "1245138602520121344",
#             "created_at": "2020-03-31T23:59:11.000Z",
#             "id": "1245138602520121344",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "700155519",
#             "conversation_id": "1245138575957639174",
#             "created_at": "2020-03-31T23:59:04.000Z",
#             "id": "1245138575957639174",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245041709500768262",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @DrJanetMorrison: My heartfelt thanks to the @ONgov and @RossRomanoSSM for this much- needed assistance. Students are struggling; this e\u2026"
#         },
#         {
#             "author_id": "258298063",
#             "conversation_id": "1245138554692325376",
#             "created_at": "2020-03-31T23:58:59.000Z",
#             "id": "1245138554692325376",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "784231129",
#             "conversation_id": "1245138554545672193",
#             "created_at": "2020-03-31T23:58:59.000Z",
#             "id": "1245138554545672193",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Trucker Blogs Application",
#             "text": "Pilot project to provide drivers access to food during Covid-19 crisis launching this weekend\n\nMore: https://t.co/m3xtsCzLYk\n\nKAMLOOPS, B.C. \u2013 What started mere days ago as an idea to get commercial drivers better access to food has quickly turned into a pilot p..."
#         },
#         {
#             "author_id": "3224765523",
#             "conversation_id": "1245138543959130112",
#             "created_at": "2020-03-31T23:58:57.000Z",
#             "id": "1245138543959130112",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 211
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244654550482649093",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @vincentdonofrio: ACTORS&amp;WRITERS couple up for FOOD BANKS.\n\u2066@briankoppelman\u2069 wrote this one for me.\nYour turn.\nAsk folks to Donate to FO\u2026"
#         },
#         {
#             "author_id": "973023727763017733",
#             "conversation_id": "1245138539538526210",
#             "created_at": "2020-03-31T23:58:56.000Z",
#             "id": "1245138539538526210",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245131282025254914",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @blowingrocketnc: As the COVID-19 pandemic results in supply shortages at grocery stores, local food producers are seeing immediate prob\u2026"
#         },
#         {
#             "author_id": "209755252",
#             "conversation_id": "1245087496389738507",
#             "created_at": "2020-03-31T23:58:55.000Z",
#             "id": "1245138536724074504",
#             "in_reply_to_user_id": "33018114",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245090401507332098",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@KirstieMAllsopp @nina_future @MartinSLewis @Tesco @AsdaServiceTeam look on Facebook  at any covid groups near him. Weve managed to get food delivered from.local companies rather than supermarkets,  lots of places seem to be advertising some sort of delivery service."
#         },
#         {
#             "author_id": "234441672",
#             "conversation_id": "1245138529052766208",
#             "created_at": "2020-03-31T23:58:53.000Z",
#             "id": "1245138529052766208",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 3
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245134020297420801",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @CAFoodPolicy: The #coronavirus hurts everyone in the food system, from farmers to restaurant servers to hungry students. You can donate\u2026"
#         },
#         {
#             "author_id": "21297583",
#             "conversation_id": "1245138523512016896",
#             "created_at": "2020-03-31T23:58:52.000Z",
#             "id": "1245138523512016896",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 80
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245095481195163648",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @IGD_News: RIP to Jake Sansom, 39, and his uncle Morris Cardinal, 57, both M\u00e9tis. Shot and killed in so-called Alberta while hunting; lo\u2026"
#         },
#         {
#             "author_id": "52004179",
#             "conversation_id": "1245138502250942464",
#             "created_at": "2020-03-31T23:58:47.000Z",
#             "id": "1245138502250942464",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "223276938",
#             "conversation_id": "1245138473461248000",
#             "created_at": "2020-03-31T23:58:40.000Z",
#             "id": "1245138473461248000",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245132825851883527",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @ListosCA: .@CAgovernor today announced the \u201cStay Home. Save Lives. Check In.\u201d campaign urging Californians to help combat social isolat\u2026"
#         },
#         {
#             "author_id": "754063477",
#             "conversation_id": "1245138448811507717",
#             "created_at": "2020-03-31T23:58:34.000Z",
#             "id": "1245138448811507717",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245109753946222595",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @TheWindsorStar: Food action plan responds to COVID-19 crisis https://t.co/2NBtgD32P6 https://t.co/FfZxS9Nag0"
#         },
#         {
#             "author_id": "982657141",
#             "conversation_id": "1245138441995780097",
#             "created_at": "2020-03-31T23:58:32.000Z",
#             "id": "1245138441995780097",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "177212515",
#             "conversation_id": "1245138433061859336",
#             "created_at": "2020-03-31T23:58:30.000Z",
#             "id": "1245138433061859336",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245111783175655424",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @LifeWaoh: COVID-19: Winners\u2019 Chapel Donates Ambulances To Lagos And Ogun States, Test Kits, Food, Others https://t.co/uIl5ik5dtb"
#         },
#         {
#             "author_id": "4539314903",
#             "conversation_id": "1245138432621510656",
#             "created_at": "2020-03-31T23:58:30.000Z",
#             "id": "1245138432621510656",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245063314541088776",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @FightBAC: Food delivery &amp; take out is the new normal for many households. Basic food handling steps will help you reduce risk of illnes\u2026"
#         },
#         {
#             "author_id": "242552877",
#             "conversation_id": "1245138410567880709",
#             "created_at": "2020-03-31T23:58:25.000Z",
#             "id": "1245138410567880709",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 46
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245094842079817728",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @DebbieRochon: PLEASE DONATE to food banks today! So important, they are counting on us. Inspired by @vincentdonofrio  idea ACTORS AND W\u2026"
#         },
#         {
#             "author_id": "71393968",
#             "conversation_id": "1245138408990633984",
#             "created_at": "2020-03-31T23:58:24.000Z",
#             "id": "1245138408990633984",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "#Thread: @TheRescueTrain volunteers, Paula &amp; Noreen, were given the duty of delivering pet food and supplies to homebound senior citizens and immune-compromised pet owners during our first Mobile Pet Assistance Event during COVID-19.  (1/3) https://t.co/4del1vh6kP"
#         },
#         {
#             "author_id": "190586896",
#             "conversation_id": "1245138380008144897",
#             "created_at": "2020-03-31T23:58:18.000Z",
#             "id": "1245138380008144897",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 46
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245094842079817728",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @DebbieRochon: PLEASE DONATE to food banks today! So important, they are counting on us. Inspired by @vincentdonofrio  idea ACTORS AND W\u2026"
#         },
#         {
#             "author_id": "20110434",
#             "conversation_id": "1245138354792009728",
#             "created_at": "2020-03-31T23:58:11.000Z",
#             "id": "1245138354792009728",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 7
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244650996388823042",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @kristingpalmer: REMINDER that the drive-up food pantry continues this week. TOMORROW, volunteers with @2ndHarvestGNOA, @evacuteer and C\u2026"
#         },
#         {
#             "author_id": "177787163",
#             "conversation_id": "1245138344155271168",
#             "created_at": "2020-03-31T23:58:09.000Z",
#             "id": "1245138344155271168",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "2993928732",
#             "conversation_id": "1245138339927412737",
#             "created_at": "2020-03-31T23:58:08.000Z",
#             "id": "1245138339927412737",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245053911804887043",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "Don, we have a drawing in my work place when you visited it. You are a legend and always smiling. \ud83d\ude18When Covid-19 is cleared and safe, please come down to @RedCliffLodge when they reopen at @SpanishPointWAW Fab views and good food. Always welcome to @ClareTourism Thank you. \ud83d\udc4f\ud83e\udd17 https://t.co/2H17QiUHyp"
#         },
#         {
#             "author_id": "2717988948",
#             "conversation_id": "1245138328640503810",
#             "created_at": "2020-03-31T23:58:05.000Z",
#             "id": "1245138328640503810",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 329
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245055880183177216",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @SinghLions: Proud to be Sikh! Gurdwara Sahib in Malerkotla, Punjab has been serving food to Muslim students since #Lockdown. The local\u2026"
#         },
#         {
#             "author_id": "245907753",
#             "conversation_id": "1245138325155074048",
#             "created_at": "2020-03-31T23:58:04.000Z",
#             "id": "1245138325155074048",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 11
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245074896935358467",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @Ecolab: Does #COVID-19 spread through food? Public health officials do not believe COVID-19 is spreading through consuming food. Howeve\u2026"
#         },
#         {
#             "author_id": "861730608552214530",
#             "conversation_id": "1245138322571382786",
#             "created_at": "2020-03-31T23:58:04.000Z",
#             "id": "1245138322571382786",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 44
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244816434577932288",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @USATODAY: \ud83c\udf2e What's better than TACO TUUUUESDAY? FREE taco Tuesday! \ud83c\udf2e\n\nTaco Bell is giving away free Doritos Locos Tacos at drive-thrus\u2026"
#         },
#         {
#             "author_id": "633176351",
#             "conversation_id": "1245138321359200258",
#             "created_at": "2020-03-31T23:58:04.000Z",
#             "id": "1245138321359200258",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 35,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 3
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "you can still smile at people in the food store and wave at people in your neighborhood without giving or getting COVID. little acts of kindness remind us we\u2019re in this together. so don\u2019t stop being kind. plz &amp; thank you \ud83d\ude0a"
#         },
#         {
#             "author_id": "873886293045989380",
#             "conversation_id": "1245138287397867523",
#             "created_at": "2020-03-31T23:57:55.000Z",
#             "id": "1245138287397867523",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 46
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245094842079817728",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @DebbieRochon: PLEASE DONATE to food banks today! So important, they are counting on us. Inspired by @vincentdonofrio  idea ACTORS AND W\u2026"
#         },
#         {
#             "author_id": "1047109120959156224",
#             "conversation_id": "1245138251796697089",
#             "created_at": "2020-03-31T23:57:47.000Z",
#             "id": "1245138251796697089",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 17
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245040805422731265",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @JCPSKY: \ud83d\udcf0 PORTAL OR PAPER | The answer is BOTH. You can access #NTILearning digitally or through hard copies. We have our new @JCPSKY C\u2026"
#         },
#         {
#             "author_id": "752488047766306817",
#             "conversation_id": "1244838372549341184",
#             "created_at": "2020-03-31T23:57:46.000Z",
#             "id": "1245138249791791107",
#             "in_reply_to_user_id": "19929890",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244838372549341184",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@BDUTT True facts ::::::: Sikhs are serving food and medicine in whole country.Hindus are donating money n building hospitals across the country.Christian praying for everyone in country, muslims are spreading covid 19 across the country after attending hazrat nizamudin."
#         },
#         {
#             "author_id": "4228940779",
#             "conversation_id": "1245138224957329410",
#             "created_at": "2020-03-31T23:57:41.000Z",
#             "id": "1245138224957329410",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 44
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245013192910286850",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "RT @vincentdonofrio: ACTORS&amp;WRITERS couple up for FOOD BANKS.\n\u2066@stevendeknight\u2069 wrote this one for me.\nYour turn.\nAsk folks to Donate to FO\u2026"
#         },
#         {
#             "author_id": "1217353631797694464",
#             "conversation_id": "1245068982383570945",
#             "created_at": "2020-03-31T23:57:32.000Z",
#             "id": "1245138188659638273",
#             "in_reply_to_user_id": "982533735307395073",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245070898945642497",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@zarrin_zubin @TheDeshBhakt @Twitter Yeah sellouts hypocrites won't go there. Knowing they'll be treated like dogs there for being non muslim. \nhttps://t.co/gQaIVxCsQc"
#         },
#         {
#             "author_id": "631171515",
#             "conversation_id": "1245138160641687552",
#             "created_at": "2020-03-31T23:57:25.000Z",
#             "id": "1245138160641687552",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 211
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244654550482649093",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @vincentdonofrio: ACTORS&amp;WRITERS couple up for FOOD BANKS.\n\u2066@briankoppelman\u2069 wrote this one for me.\nYour turn.\nAsk folks to Donate to FO\u2026"
#         },
#         {
#             "author_id": "2932871283",
#             "conversation_id": "1245138139804577792",
#             "created_at": "2020-03-31T23:57:20.000Z",
#             "id": "1245138139804577792",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "224495471",
#             "conversation_id": "1245138135459098625",
#             "created_at": "2020-03-31T23:57:19.000Z",
#             "id": "1245138135459098625",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 23
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245137729467199488",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "TweetDeck",
#             "text": "RT @LizMinchin: #Google trends show many #NewZealanders are also asking whether you can catch #Covid_19nz from surfaces\n\nHere's a useful @C\u2026"
#         },
#         {
#             "author_id": "1120124541865353216",
#             "conversation_id": "1245138123136176128",
#             "created_at": "2020-03-31T23:57:16.000Z",
#             "id": "1245138123136176128",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 498
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245087302331715585",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @cjwerleman: With no medical equipment and diminishing food supplies, Rohingya Muslim refugees have been left alone as COVID-19 stalks t\u2026"
#         },
#         {
#             "author_id": "429460936",
#             "conversation_id": "1245138110670934017",
#             "created_at": "2020-03-31T23:57:13.000Z",
#             "id": "1245138110670934017",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "After 18-hour shifts trying to save our lives from COVID-19, NHS Hospital Staff are faced with canteens that shut at 5pm. Help @MealsForTheNHS get food to wards, today.  https://t.co/nFGpoQhh5V #FeedTheNHS"
#         },
#         {
#             "author_id": "211218111",
#             "conversation_id": "1245138108020072448",
#             "created_at": "2020-03-31T23:57:13.000Z",
#             "id": "1245138108020072448",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 9
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245135285425516551",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @SethAndrewsTTA: In case of emergency, feel free to use me as an alternate food source. https://t.co/b1hziny6Xu"
#         },
#         {
#             "author_id": "1419354229",
#             "conversation_id": "1245138077523365888",
#             "created_at": "2020-03-31T23:57:05.000Z",
#             "id": "1245138077523365888",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 409
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245112160012980224",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @RalphNader: Not giving undocumented workers insurance for COVID-19 is foolhardy. Do we want these workers who harvest our food, serve o\u2026"
#         },
#         {
#             "author_id": "15569772",
#             "conversation_id": "1245115090183041026",
#             "created_at": "2020-03-31T23:57:05.000Z",
#             "id": "1245138074348269568",
#             "in_reply_to_user_id": "828613457020870657",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245115090183041026",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@SecretaryCarson @SenRickScott Something needs 2B done about @GovRonDeSantis\nlack of leadership. Waited 2long 2close beaches $$ came 1st. No emergency food stamps. Unemployment jammed! No order 2halt evictions/foreclosures 4 those forced out of work!Lost my vote! #RonDeSantis \n@realDonaldTrump @FoxNews @VP"
#         },
#         {
#             "author_id": "318430281",
#             "conversation_id": "1245138010720669697",
#             "created_at": "2020-03-31T23:56:49.000Z",
#             "id": "1245138010720669697",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 5661
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244320649876836352",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @carolecadwalla: Amazing. Ocado orders 100,000 Covid-19 tests for staff to ensure it can keep food deliveries going. Unbelievable govt c\u2026"
#         },
#         {
#             "author_id": "773359969102024710",
#             "conversation_id": "1245137955456536577",
#             "created_at": "2020-03-31T23:56:36.000Z",
#             "id": "1245137955456536577",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 76060
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244441917582200833",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @LiataisLibrary: Heads up for folks in the USA; \n\nIf you're not having a food emergency, please don't go to the grocery store on April 1\u2026"
#         },
#         {
#             "author_id": "15569772",
#             "conversation_id": "1245137903933587461",
#             "created_at": "2020-03-31T23:56:24.000Z",
#             "id": "1245137903933587461",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244741071265038336",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Something needs 2B done about @GovRonDeSantis\nlack of leadership. Waited 2long 2close beaches $$ came 1st. No emergency food stamps. Unemployment jammed! No order 2halt evictions/foreclosures 4 those forced out of work!Lost my vote! #RonDeSantis \n@realDonaldTrump @FoxNews @VP https://t.co/DlBJdFOR0R"
#         },
#         {
#             "author_id": "15569772",
#             "conversation_id": "1244741071265038336",
#             "created_at": "2020-03-31T23:56:17.000Z",
#             "id": "1245137873873047552",
#             "in_reply_to_user_id": "822215673812119553",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1244741071265038336",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@WhiteHouse @SecondLady Something needs 2B done about @GovRonDeSantis\nlack of leadership. Waited 2long 2close beaches $$ came 1st. No emergency food stamps. Unemployment jammed! No order 2halt evictions/foreclosures 4 those forced out of work!Lost my vote! #RonDeSantis \n@realDonaldTrump @FoxNews @VP"
#         },
#         {
#             "author_id": "101835305",
#             "conversation_id": "1245137863466864640",
#             "created_at": "2020-03-31T23:56:14.000Z",
#             "id": "1245137863466864640",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 119
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245079745538084864",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @CAgovernor: During CA\u2019s stay at home order, older Californians may need friends &amp; neighbors to obtain basic necessities like groceries\u2026"
#         },
#         {
#             "author_id": "943156513215881216",
#             "conversation_id": "1245137861906542592",
#             "created_at": "2020-03-31T23:56:14.000Z",
#             "id": "1245137861906542592",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245135784694419457",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @FoodBankCENC: Partnership Power! Thank you for supporting our #COVID19 Response! https://t.co/CFgf7RisRv"
#         },
#         {
#             "author_id": "796262397119987712",
#             "conversation_id": "1245137836510072832",
#             "created_at": "2020-03-31T23:56:08.000Z",
#             "id": "1245137836510072832",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 409
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245112160012980224",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @RalphNader: Not giving undocumented workers insurance for COVID-19 is foolhardy. Do we want these workers who harvest our food, serve o\u2026"
#         },
#         {
#             "author_id": "83674758",
#             "conversation_id": "1245137822756900865",
#             "created_at": "2020-03-31T23:56:05.000Z",
#             "id": "1245137822756900865",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 183
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1245076579669032960",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @LiquidDominate: I got super sick with food poisoning in july of last year and ended up having to go to the emergency room, just got the\u2026"
#         },
#         {
#             "author_id": "765069026234105856",
#             "conversation_id": "1245137815546953728",
#             "created_at": "2020-03-31T23:56:03.000Z",
#             "id": "1245137815546953728",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
# ...
#                 "description": "no fasci, no grillini, no fascio-leghisti, orfana di centro-sinistra serio, riformista. Cultura, lavoro, giustizia sociale, ambiente. In ogni caso Carpe Diem \u2600\ufe0f",
#                 "id": "920932258407763969",
#                 "name": "Faby",
#                 "public_metrics": {
#                     "followers_count": 537,
#                     "following_count": 1492,
#                     "listed_count": 1,
#                     "tweet_count": 35706
#                 },
#                 "username": "FogliFabiana",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-09-15T20:52:43.000Z",
#                 "description": "Florida Politics is a new media concern covering campaigns, elections, government, policy, and lobbying in Florida.",
#                 "id": "2811924896",
#                 "name": "Florida Politics",
#                 "public_metrics": {
#                     "followers_count": 28309,
#                     "following_count": 984,
#                     "listed_count": 571,
#                     "tweet_count": 73012
#                 },
#                 "username": "Fla_Pol",
#                 "verified": true
#             },
#             {
#                 "created_at": "2018-12-30T18:49:57.000Z",
#                 "description": "|Free Kashmir|-Free Palestine\ud83c\uddf5\ud83c\uddf8 #Blacklivesmatter|-Restore Humanity|",
#                 "id": "1079449526547726336",
#                 "name": "youprobablyknowme. #SaveKashmir",
#                 "public_metrics": {
#                     "followers_count": 50,
#                     "following_count": 216,
#                     "listed_count": 0,
#                     "tweet_count": 23945
#                 },
#                 "username": "iihumanitarian",
#                 "verified": false
#             },
#             {
#                 "created_at": "2016-07-23T19:42:15.000Z",
#                 "description": "Stay afraid, but do it anyway \ud83d\udc96\ud83d\udc9c\ud83d\udc99 she/her",
#                 "id": "756937487377891329",
#                 "name": "Kiersten",
#                 "public_metrics": {
#                     "followers_count": 182,
#                     "following_count": 228,
#                     "listed_count": 3,
#                     "tweet_count": 16645
#                 },
#                 "username": "LeiaOrganza",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-05-06T09:44:57.000Z",
#                 "description": "Agricultural market analyst. Croc wearer. Scottish accent - not Irish. Pig farmer. Co-lead @TEMarkets. Podcast: @AgWatchers Columnist with @wabusinessnews",
#                 "id": "38148009",
#                 "name": "Andrew Whitelaw",
#                 "public_metrics": {
#                     "followers_count": 5311,
#                     "following_count": 4182,
#                     "listed_count": 48,
#                     "tweet_count": 13038
#                 },
#                 "username": "WheatWatcher",
#                 "verified": false
#             },
#             {
#                 "created_at": "2016-09-26T23:49:44.000Z",
#                 "description": "Deputy Leader of @The_Nationals. Minister for Agriculture and Northern Australia and Member for Maranoa. Advocate for rural communities.",
#                 "id": "780554980847517696",
#                 "name": "David Littleproud MP",
#                 "public_metrics": {
#                     "followers_count": 10401,
#                     "following_count": 384,
#                     "listed_count": 191,
#                     "tweet_count": 1111
#                 },
#                 "username": "D_LittleproudMP",
#                 "verified": true
#             },
#             {
#                 "created_at": "2018-11-06T13:51:30.000Z",
#                 "description": "ADIOS. HARDSPACE: SHIPBREAKER. PARATOPIC. Narrative Designer. Hired Gun. Shotgun scientist.\n\nhttps://t.co/Qb8syHLDcF\n\nhttps://t.co/PUiD0K0jax",
#                 "id": "1059805476542509057",
#                 "name": "doctober",
#                 "public_metrics": {
#                     "followers_count": 11541,
#                     "following_count": 1176,
#                     "listed_count": 91,
#                     "tweet_count": 182814
#                 },
#                 "username": "docsquiddy",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-04-17T04:57:21.000Z",
#                 "description": "FL's first LGBTQ Latino legislator. FL House District 49. He/him/\u00e9l. Good husband, brother, son, + favorite guncle. https://t.co/ZLBg3vqBD1",
#                 "id": "32313637",
#                 "name": "Rep. Carlos G Smith",
#                 "public_metrics": {
#                     "followers_count": 28275,
#                     "following_count": 3669,
#                     "listed_count": 276,
#                     "tweet_count": 16402
#                 },
#                 "username": "CarlosGSmith",
#                 "verified": true
#             },
#             {
#                 "created_at": "2015-07-27T07:28:43.000Z",
#                 "description": "Check out my music! pls",
#                 "id": "3297045690",
#                 "name": "Connor Reid",
#                 "public_metrics": {
#                     "followers_count": 1056,
#                     "following_count": 1486,
#                     "listed_count": 6,
#                     "tweet_count": 44230
#                 },
#                 "username": "connorreidmusic",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-01-31T09:38:06.000Z",
#                 "description": "",
#                 "id": "245282047",
#                 "name": "Fiona C",
#                 "public_metrics": {
#                     "followers_count": 25,
#                     "following_count": 156,
#                     "listed_count": 0,
#                     "tweet_count": 104
#                 },
#                 "username": "Fiona__Tweets",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-03-25T23:38:13.000Z",
#                 "description": "",
#                 "id": "2436760409",
#                 "name": "Joahnny",
#                 "public_metrics": {
#                     "followers_count": 321,
#                     "following_count": 2614,
#                     "listed_count": 25,
#                     "tweet_count": 9672
#                 },
#                 "username": "johnsuarezred",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-11-17T10:28:14.000Z",
#                 "description": "Health Correspondent, RT\u00c9 News, Ireland. NUJ journalist for 40 + years. Views here my own, not RTE\u2019s. Re-tweets not an endorsement.",
#                 "id": "216647845",
#                 "name": "Fergal Bowers",
#                 "public_metrics": {
#                     "followers_count": 125155,
#                     "following_count": 19948,
#                     "listed_count": 472,
#                     "tweet_count": 21594
#                 },
#                 "username": "FergalBowers",
#                 "verified": true
#             },
#             {
#                 "created_at": "2009-09-21T20:29:35.000Z",
#                 "description": "Husband | Dad | @universityofga and @samfordu alum | former @schwarzenegger senior staff | former @calpers board member | Chair @TheCAMuseum",
#                 "id": "76133717",
#                 "name": "Richard Costigan",
#                 "public_metrics": {
#                     "followers_count": 4073,
#                     "following_count": 5084,
#                     "listed_count": 175,
#                     "tweet_count": 46155
#                 },
#                 "username": "richardcostigan",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-07-09T14:30:24.000Z",
#                 "description": "Vitreo-Retina surgeon,Nationalist, a Red devil, CR7 fan and ........\ud83d\ude0e\ud83d\ude0e\ud83d\ude0e",
#                 "id": "55250609",
#                 "name": "Photopsia \u26a1\u26a1\ud83d\udc40\u2695\ufe0f\u26d1\ufe0f\ud83d\udc89\ud83d\udc8a\u2622\ufe0f\ud83c\uddee\ud83c\uddf3",
#                 "public_metrics": {
#                     "followers_count": 559,
#                     "following_count": 1981,
#                     "listed_count": 1,
#                     "tweet_count": 18653
#                 },
#                 "username": "Moneesh17",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-11-21T16:53:22.000Z",
#                 "description": "Sociology PhD candidate at the University of Michigan studying how colleges cover up sexual violence and the impact on survivors.",
#                 "id": "2887091908",
#                 "name": "Nicole Bedera",
#                 "public_metrics": {
#                     "followers_count": 20969,
#                     "following_count": 5465,
#                     "listed_count": 129,
#                     "tweet_count": 10763
#                 },
#                 "username": "NBedera",
#                 "verified": false
#             },
#             {
#                 "created_at": "2013-04-21T23:26:48.000Z",
#                 "description": "Retired attorney and legislative intent researcher, traveler with great hubby, busy mom, happy grandmother, opinionated citizen, reader, and voting Californian.",
#                 "id": "1370802067",
#                 "name": "Ita Sanders",
#                 "public_metrics": {
#                     "followers_count": 447,
#                     "following_count": 107,
#                     "listed_count": 4,
#                     "tweet_count": 30399
#                 },
#                 "username": "Itasanders",
#                 "verified": false
#             },
#             {
#                 "created_at": "2016-10-16T15:30:19.000Z",
#                 "description": "leans left of liberal; former lawyer, married with 2 delicious sons + 2 sweet fur-babies",
#                 "id": "787677057656451074",
#                 "name": "Dee",
#                 "public_metrics": {
#                     "followers_count": 233,
#                     "following_count": 2349,
#                     "listed_count": 0,
#                     "tweet_count": 8232
#                 },
#                 "username": "dorysu9",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-07-14T17:57:29.000Z",
#                 "description": "Official account of the Florida House Republican Majority Conference. Following does not equal endorsement, friendship, or viewpoint.",
#                 "id": "56764250",
#                 "name": "FL House Republicans",
#                 "public_metrics": {
#                     "followers_count": 13266,
#                     "following_count": 3196,
#                     "listed_count": 239,
#                     "tweet_count": 3350
#                 },
#                 "username": "FLGOPMajority",
#                 "verified": false
#             },
#             {
#                 "created_at": "2015-09-28T15:21:08.000Z",
#                 "description": "Ex labour member and born Socialist. Thought I could stay and help make a difference but can't forgive and forget the treacherous backstabbing bastards.\nAVFC.\ud83d\udc99",
#                 "id": "3805014508",
#                 "name": "Socialist Gorilla",
#                 "public_metrics": {
#                     "followers_count": 975,
#                     "following_count": 1321,
#                     "listed_count": 4,
#                     "tweet_count": 26719
#                 },
#                 "username": "62Englishman",
#                 "verified": false
#             },
#             {
#                 "created_at": "2015-06-03T04:24:19.000Z",
#                 "description": "@ztdauburn \ud83d\udc95",
#                 "id": "3306699303",
#                 "name": "\u210d\ud835\udd38\u2115\u2115\ud835\udd38\u210d \ud83c\udf3b",
#                 "public_metrics": {
#                     "followers_count": 509,
#                     "following_count": 607,
#                     "listed_count": 0,
#                     "tweet_count": 11628
#                 },
#                 "username": "hannahep99",
#                 "verified": false
#             },
#             {
#                 "created_at": "2013-11-01T19:37:06.000Z",
#                 "description": "i c u & u o e n o",
#                 "id": "2168977388",
#                 "name": "\ud83d\udc7b in the \ud83d\udcbb",
#                 "public_metrics": {
#                     "followers_count": 75,
#                     "following_count": 531,
#                     "listed_count": 1,
#                     "tweet_count": 1851
#                 },
#                 "username": "reecald",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-01-22T22:33:01.000Z",
#                 "description": "As Neighbourhood Director of Stone Soup Network I will continue to work with our community to provide support to those who need a helping hand.",
#                 "id": "107539285",
#                 "name": "Sarah Doucette",
#                 "public_metrics": {
#                     "followers_count": 8125,
#                     "following_count": 395,
#                     "listed_count": 274,
#                     "tweet_count": 38975
#                 },
#                 "username": "SarahEDoucette",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-10-29T14:17:23.000Z",
#                 "description": "Muslim, Husband, Father and special needs parent, Engineer, Googler. Formerly Red Hat, Oracle. Tweets and opinions are my own.",
#                 "id": "912533072",
#                 "name": "Ti",
#                 "public_metrics": {
#                     "followers_count": 396,
#                     "following_count": 249,
#                     "listed_count": 11,
#                     "tweet_count": 6464
#                 },
#                 "username": "chumboslice",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-03-02T18:48:34.000Z",
#                 "description": "",
#                 "id": "837374086473003008",
#                 "name": "LaVergne Skills USA",
#                 "public_metrics": {
#                     "followers_count": 129,
#                     "following_count": 450,
#                     "listed_count": 0,
#                     "tweet_count": 254
#                 },
#                 "username": "LHSCJSkillsUSA",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-05-21T19:40:40.000Z",
#                 "description": "CDC's official Twitter source for daily credible health & safety updates from Centers for Disease Control & Prevention. Privacy policy: https://t.co/N3OhkbXTAq",
#                 "id": "146569971",
#                 "name": "CDC",
#                 "public_metrics": {
#                     "followers_count": 4281147,
#                     "following_count": 271,
#                     "listed_count": 19270,
#                     "tweet_count": 31540
#                 },
#                 "username": "CDCgov",
#                 "verified": true
#             },
#             {
#                 "created_at": "2015-09-11T02:09:58.000Z",
#                 "description": "Infinity!",
#                 "id": "3521785874",
#                 "name": "Michael Peters",
#                 "public_metrics": {
#                     "followers_count": 3199,
#                     "following_count": 4998,
#                     "listed_count": 29,
#                     "tweet_count": 314196
#                 },
#                 "username": "michaelepeters7",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1245138803695611905",
#         "next_token": "b26v89c19zqg8o3fo77fgn2263e893g2l54ug9nk3gm0t",
#         "oldest_id": "1245131736507285506",
#         "result_count": 498
#     }
# }

# %%
# Create file
csvFile = open("data.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
append_to_csv(json_response, "data.csv")
# Out:
# # of Tweets added from this response:  498

# %% [markdown]
# # Looping

# %%
# Create file
csvFile = open("data.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %%
#Inputs for tweets
headers = create_headers(bearer_token)
keyword = "food emergency OR food crisis OR food aid OR food need OR food corona OR food rona OR food assistance OR food distribution OR food distribute OR food free OR WIC OR food security OR food insecurity OR food hungry OR #freefood OR #mealservice OR food pantry OR food bank OR covid food -is:retweet -RT"
start_list =    ['2020-03-01T00:00:00.000Z',
                 '2020-04-01T00:00:00.000Z',
                 '2020-05-01T00:00:00.000Z']

end_list =      ['2020-03-31T00:00:00.000Z',
                 '2020-04-30T00:00:00.000Z',
                 '2020-05-31T00:00:00.000Z']
max_results = 500

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open("data.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 500 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "data.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, "data.csv")
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77f1u9ogsiggsvd990gyz2jhagsd
# Start Date:  2020-03-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  486
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo77f1u9ogsiggsvd990gyz2jhagsd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77f1u9of9of8c348avsi99lk8xod
# Start Date:  2020-03-01T00:00:00.000Z
# # of Tweets added from this response:  491
# Total # of Tweets added:  977
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7af8tr6xg9bb0uqyxgyjubly5v99
# Start Date:  2020-04-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  1465
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo7af8tr6xg9bb0uqyxgyjubly5v99
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7af8tr6sx8swoalkt5qpfgqjqhdp
# Start Date:  2020-04-01T00:00:00.000Z
# # of Tweets added from this response:  493
# Total # of Tweets added:  1958
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dffzoz5j1e9sxyvixtf25oi2dtp
# Start Date:  2020-05-01T00:00:00.000Z
# # of Tweets added from this response:  440
# Total # of Tweets added:  2398
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo7dffzoz5j1e9sxyvixtf25oi2dtp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dffzooqqmlho9x1i341tbsdwjnh
# Start Date:  2020-05-01T00:00:00.000Z
# # of Tweets added from this response:  431
# Total # of Tweets added:  2829
# -------------------
# Total number of results:  2829
