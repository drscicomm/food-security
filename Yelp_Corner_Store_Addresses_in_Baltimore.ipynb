# %% [markdown]
# <a href="https://colab.research.google.com/github/drscicomm/food-security/blob/main/Yelp_Corner_Store_Addresses_in_Baltimore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Made API request using postman

# %%
import requests
import json
import csv

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?term=corner store&location=baltimore&limit=40&offset=100"

payload={}
headers = {
  'authorization': 'Bearer Kd9EBpsCWfKLxV_2QnY8rnS4pqCCR9KUj7VMne_9jNAbB2UIxnyHUog9f-oXvXLhixQByTNVJhxTrw0a0ph59mL-ZgRk13GzWo38IXNy82_w6OriLSyDC87lPDmZYnYx',
  'Kd9EBpsCWfKLxV_2QnY8rnS4pqCCR9KUj7VMne_9jNAbB2UIxnyHUog9f-oXvXLhixQByTNVJhxTrw0a0ph59mL-ZgRk13GzWo38IXNy82_w6OriLSyDC87lPDmZYnYx': ''
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"businesses": [{"id": "yQDZfy0nCyMRAiykpd5b_Q", "alias": "geresbecks-middle-river", "name": "Geresbeck's", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/e4MuIuhZSQDmenY0K0KtGQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/geresbecks-middle-river?adjust_creative=2uIj14Uc3o_bLRVBDjeciA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2uIj14Uc3o_bLRVBDjeciA", "review_count": 37, "categories": [{"alias": "grocery", "title": "Grocery"}], "rating": 3.5, "coordinates": {"latitude": 39.327725, "longitude": -76.44077}, "transactions": [], "price": "$", "location": {"address1": "2109 Eastern Blvd", "address2": "", "address3": "Hawthorne Shopping Ctr", "city": "Middle River", "zip_code": "21220", "country": "US", "state": "MD", "display_address": ["2109 Eastern Blvd", "Hawthorne Shopping Ctr", "Middle River, MD 21220"]}, "phone": "+14106863487", "display_phone": "(410) 686-3487", "distance": 14619.722844943753}, {"id": "4iTgpJ8Fri5-IOlmF65nsw", "alia
# ...

# %%
data = response.json()

# %%
# Print each value

stores_list = data['businesses']
for store in stores_list:
  print(store['coordinates']['latitude'])
# Out:
# 39.327725
# 39.27871
# 39.2775711348358
# 39.2819
# 39.39756533
# 39.3681165618145
# 39.272037
# 39.378192098369
# 39.3309324
# 39.39892
# 39.3031730651855
# 39.3269
# 39.28593
# 39.3478622436523
# 39.367
# 39.28541
# 39.332481
# 39.2857429
# 39.2824344
# 39.37127
# 39.33176
# 39.27986
# 39.3312237977422
# 39.4308233163568
# 39.2728615
# 39.2661560880948
# 39.36842262664239
# 39.27581
# 39.2748108
# 39.350131
# 39.320921
# 39.1646
# 39.3443978
# 39.278658
# 39.3802624258251
# 39.3277893
# 39.291266
# 39.3003015
# 39.3135963857557
# 39.28277

# %%
with open('cornerstores_baltimore.csv', mode='w') as CSVFile:
    writer = csv.writer(CSVFile, delimiter=",")

    writer.writerow([
        "id",
        "alias",
        "name",
        "url",
        "latitude",
        "longitude",
        "address1",
        "address2",
        "city",
        "state"
        "zip_code"
    ])

    for store in stores_list:
        row = []
        id = store["id"]
        alias = store["alias"]
        name = store["name"]
        url = store["url"]
        latitude = store["coordinates"]["latitude"]
        longitude = store["coordinates"]["longitude"]
        address1 = store["location"]["address1"]
        address2 = store["location"]["address2"]
        city = store["location"]["city"]
        state = store["location"]["state"]
        zip_code = store["location"]["zip_code"]

        

        row.append(id)
        row.append(alias)
        row.append(name)
        row.append(review_count)
        row.append(rating)
        row.append(url)
        row.append(latitude)
        row.append(longitude)
        row.append(address1)
        row.append(address2)
        row.append(city)
        row.append(state)
        row.append(zip_code)
        
        writer.writerow(row)
